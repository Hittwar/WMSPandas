# %%
from mocanexion import MocaNexion2
import pandas as pd
moca = MocaNexion2()
moca.connect("https://url/service", "super", "SUPER", device=None, warehouse=None, locale=None)
status, res = moca.execute("list inventory where arecod = 'A01ALM-GR1'")
df = pd.DataFrame(res)
df.head()
# Out:
#        arecod bldg_id wh_id           stoloc picked_flg        lodnum  \
# 0  A01ALM-GR1     A01  FMZA  1GR1-1-02M-002B          0  122222222222
# 1  A01ALM-GR1     A01  FMZA  1GR1-1-02M-002B          0  L00000000C8C
# 2  A01ALM-GR1     A01  FMZA  1GR1-1-02M-002B          0  L00000000C8D
# 3  A01ALM-GR1     A01  FMZA  1GR1-1-02M-004A          0  L00000000C8I
# 4  A01ALM-GR1     A01  FMZA  1GR1-1-02M-006A          0  L00000000C8J
#
#   asset_typ lodtag        subnum sub_asset_typ  ... inv_attr_dte2  \
# 0      None   None  S0000000091F          None  ...          None
# 1      None   None  S0000000091D          None  ...          None
# 2      None   None  S0000000091E          None  ...          None
# 3      None   None  S0000000091Q          None  ...          None
# 4      None   None  S0000000091T          None  ...          None
#
#            lstmov          lstdte cstms_cnsgnmnt_id rttn_id cstms_bond_flg  \
# ...

# %%
df['arecod'].count()
# Out:
# 49

# %%
import certifi
certifi.where()
# Out:
# 'C:\\Users\\jorge.polanco\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\certifi\\cacert.pem'
